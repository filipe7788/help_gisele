# %%
# imports
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# lista aleatória
matriz = [1, 2, 3, 4, 5, 6, 7, 8, 9]

# digamos que a quantidade de itens no eixo X seja 3 e no Y seja 3
lista_de_itens_em_X = [0, 1, 2]
lista_de_itens_em_Y =  [0, 1, 2]

matriz = np.array(matriz).reshape(3, 3) # ou len(X), len(Y)

fig, ax = plt.subplots(figsize=(12,8))
s = sns.heatmap(matriz, square=False, cmap="rocket_r") #cmap é o estilo desse degradẽ específico
plt.show()
